# %%
#import all the dependencies
import pandas as pd
import numpy as np
import requests

#import Weather API key
from config import weather_api_key

# %%
# Create 2000 random latituds and longitudes using np.random
lats = np.random.uniform(low = -90, high = 90, size = 2000)
longs = np.random.uniform(low = -180, high = 180, size = 2000)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(zip(lats, longs))

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Starting URL for Weather Map API Call.
url = ("http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" 
       + weather_api_key)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                          
                          "Current Description": city_weather_description
                          })
    # If an error is experienced, skip the city.
    except:
        print(f'City "{city}" not found. Skipping...')
        pass  
        
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yeppoon
# Processing Record 2 of Set 1 | pavilosta
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | preobrazheniye
# Processing Record 6 of Set 1 | darnah
# Processing Record 7 of Set 1 | syedove
# Processing Record 8 of Set 1 | lagoa
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | pecos
# Processing Record 12 of Set 1 | lerwick
# Processing Record 13 of Set 1 | manicore
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | carutapera
# Processing Record 17 of Set 1 | cotonou
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | tarko-sale
# Processing Record 21 of Set 1 | taolanaro
# City "taolanaro" not found. Skipping...
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | morehead
# Processing Record 24 of Set 1 | mys shmidta
# City "mys shmidta" not found. Skipping...
# Processing Record 25 of Set 1 | balykshi
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | tarudant
# City "tarudant" not found. Skipping...
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | husavik
# Processing Record 31 of Set 1 | sioux lookout
# Processing Record 32 of Set 1 | college
# Processing Record 33 of Set 1 | saint-denis
# Processing Record 34 of Set 1 | sorland
# Processing Record 35 of Set 1 | usak
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | viedma
# Processing Record 40 of Set 1 | souillac
# Processing Record 41 of Set 1 | muros
# Processing Record 42 of Set 1 | ahipara
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | zuenoula
# Processing Record 46 of Set 1 | pacifica
# Processing Record 47 of Set 1 | anadyr
# Processing Record 48 of Set 1 | pravia
# Processing Record 49 of Set 1 | torbay
# Processing Record 50 of Set 1 | manzanillo
# Processing Record 1 of Set 2 | upernavik
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | margate
# Processing Record 4 of Set 2 | samarai
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | lorengau
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | sorvag
# City "sorvag" not found. Skipping...
# Processing Record 9 of Set 2 | oistins
# Processing Record 10 of Set 2 | illoqqortoormiut
# City "illoqqortoormiut" not found. Skipping...
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | te anau
# Processing Record 15 of Set 2 | soyo
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | andenes
# Processing Record 18 of Set 2 | wattegama
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | bodden town
# Processing Record 21 of Set 2 | bangassou
# Processing Record 22 of Set 2 | agirish
# Processing Record 23 of Set 2 | cherskiy
# Processing Record 24 of Set 2 | idil
# Processing Record 25 of Set 2 | mancio lima
# Processing Record 26 of Set 2 | yopal
# Processing Record 27 of Set 2 | bourail
# Processing Record 28 of Set 2 | laguna
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | alofi
# Processing Record 31 of Set 2 | ancud
# Processing Record 32 of Set 2 | karousades
# City "karousades" not found. Skipping...
# Processing Record 33 of Set 2 | arlit
# Processing Record 34 of Set 2 | sangar
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | pinega
# Processing Record 40 of Set 2 | kruisfontein
# Processing Record 41 of Set 2 | barentsburg
# City "barentsburg" not found. Skipping...
# Processing Record 42 of Set 2 | bambous virieux
# Processing Record 43 of Set 2 | vostok
# Processing Record 44 of Set 2 | verkhnevilyuysk
# Processing Record 45 of Set 2 | kodiak
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | vila velha
# Processing Record 48 of Set 2 | chino valley
# Processing Record 49 of Set 2 | muskegon
# Processing Record 50 of Set 2 | mehamn
# Processing Record 1 of Set 3 | olafsvik
# Processing Record 2 of Set 3 | bur gabo
# City "bur gabo" not found. Skipping...
# Processing Record 3 of Set 3 | albany
# Processing Record 4 of Set 3 | lamidan
# City "lamidan" not found. Skipping...
# Processing Record 5 of Set 3 | inhambane
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | san quintin
# Processing Record 10 of Set 3 | nanortalik
# Processing Record 11 of Set 3 | carnarvon
# Processing Record 12 of Set 3 | northallerton
# Processing Record 13 of Set 3 | cambridge
# Processing Record 14 of Set 3 | quatre cocos
# Processing Record 15 of Set 3 | saint george
# Processing Record 16 of Set 3 | san jose
# Processing Record 17 of Set 3 | kutum
# Processing Record 18 of Set 3 | mitchell
# Processing Record 19 of Set 3 | ulaangom
# Processing Record 20 of Set 3 | kieta
# Processing Record 21 of Set 3 | tasiilaq
# Processing Record 22 of Set 3 | takapau
# Processing Record 23 of Set 3 | talaya
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | sault sainte marie
# Processing Record 26 of Set 3 | belmonte
# Processing Record 27 of Set 3 | georgetown
# Processing Record 28 of Set 3 | thinadhoo
# Processing Record 29 of Set 3 | kahului
# Processing Record 30 of Set 3 | buala
# Processing Record 31 of Set 3 | longyearbyen
# Processing Record 32 of Set 3 | kaitangata
# Processing Record 33 of Set 3 | zambezi
# Processing Record 34 of Set 3 | geraldton
# Processing Record 35 of Set 3 | flin flon
# Processing Record 36 of Set 3 | atuona
# Processing Record 37 of Set 3 | touros
# Processing Record 38 of Set 3 | la ronge
# Processing Record 39 of Set 3 | mayo
# Processing Record 40 of Set 3 | chulman
# Processing Record 41 of Set 3 | narsaq
# Processing Record 42 of Set 3 | myshkin
# Processing Record 43 of Set 3 | thompson
# Processing Record 44 of Set 3 | pevek
# Processing Record 45 of Set 3 | belushya guba
# City "belushya guba" not found. Skipping...
# Processing Record 46 of Set 3 | paradwip
# City "paradwip" not found. Skipping...
# Processing Record 47 of Set 3 | newport
# Processing Record 48 of Set 3 | kaeo
# Processing Record 49 of Set 3 | plouzane
# Processing Record 50 of Set 3 | gao
# Processing Record 1 of Set 4 | seoul
# Processing Record 2 of Set 4 | chabahar
# Processing Record 3 of Set 4 | ribeira grande
# Processing Record 4 of Set 4 | hamilton
# Processing Record 5 of Set 4 | aklavik
# Processing Record 6 of Set 4 | normandin
# Processing Record 7 of Set 4 | lulea
# Processing Record 8 of Set 4 | bay roberts
# Processing Record 9 of Set 4 | khandyga
# Processing Record 10 of Set 4 | oksfjord
# Processing Record 11 of Set 4 | bartica
# Processing Record 12 of Set 4 | nizhneyansk
# City "nizhneyansk" not found. Skipping...
# Processing Record 13 of Set 4 | qaanaaq
# Processing Record 14 of Set 4 | tuktoyaktuk
# Processing Record 15 of Set 4 | lavrentiya
# Processing Record 16 of Set 4 | meulaboh
# Processing Record 17 of Set 4 | jiddah
# City "jiddah" not found. Skipping...
# Processing Record 18 of Set 4 | bokoro
# Processing Record 19 of Set 4 | star
# Processing Record 20 of Set 4 | kangaatsiaq
# Processing Record 21 of Set 4 | nyimba
# Processing Record 22 of Set 4 | barra patuca
# Processing Record 23 of Set 4 | kamiiso
# Processing Record 24 of Set 4 | kaduqli
# Processing Record 25 of Set 4 | maarianhamina
# Processing Record 26 of Set 4 | constitucion
# Processing Record 27 of Set 4 | talnakh
# Processing Record 28 of Set 4 | pulaski
# Processing Record 29 of Set 4 | rurrenabaque
# Processing Record 30 of Set 4 | la sarre
# Processing Record 31 of Set 4 | bom jesus
# Processing Record 32 of Set 4 | meiganga
# Processing Record 33 of Set 4 | samusu
# City "samusu" not found. Skipping...
# Processing Record 34 of Set 4 | namatanai
# Processing Record 35 of Set 4 | malia
# Processing Record 36 of Set 4 | isangel
# Processing Record 37 of Set 4 | norman wells
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | maxixe
# Processing Record 40 of Set 4 | oranjemund
# Processing Record 41 of Set 4 | chuy
# Processing Record 42 of Set 4 | qiongshan
# Processing Record 43 of Set 4 | ossora
# Processing Record 44 of Set 4 | zima
# Processing Record 45 of Set 4 | abejorral
# Processing Record 46 of Set 4 | kyzyl-suu
# Processing Record 47 of Set 4 | makinsk
# Processing Record 48 of Set 4 | griffith
# Processing Record 49 of Set 4 | bendigo
# Processing Record 50 of Set 4 | fuling
# Processing Record 1 of Set 5 | vanderhoof
# Processing Record 2 of Set 5 | attawapiskat
# City "attawapiskat" not found. Skipping...
# Processing Record 3 of Set 5 | waingapu
# Processing Record 4 of Set 5 | los andes
# Processing Record 5 of Set 5 | gien
# Processing Record 6 of Set 5 | shingu
# Processing Record 7 of Set 5 | moron
# Processing Record 8 of Set 5 | alexandria
# Processing Record 9 of Set 5 | ambilobe
# Processing Record 10 of Set 5 | cururupu
# Processing Record 11 of Set 5 | aflu
# City "aflu" not found. Skipping...
# Processing Record 12 of Set 5 | hwange
# Processing Record 13 of Set 5 | sainte-maxime
# Processing Record 14 of Set 5 | flinders
# Processing Record 15 of Set 5 | fairbanks
# Processing Record 16 of Set 5 | kiunga
# Processing Record 17 of Set 5 | bubaque
# Processing Record 18 of Set 5 | pisco
# Processing Record 19 of Set 5 | horki
# Processing Record 20 of Set 5 | esperance
# Processing Record 21 of Set 5 | lima
# Processing Record 22 of Set 5 | karratha
# Processing Record 23 of Set 5 | dingle
# Processing Record 24 of Set 5 | sibu
# Processing Record 25 of Set 5 | pokhara
# Processing Record 26 of Set 5 | ndago
# Processing Record 27 of Set 5 | camapua
# Processing Record 28 of Set 5 | eydhafushi
# Processing Record 29 of Set 5 | ciudad guayana
# Processing Record 30 of Set 5 | kouroussa
# Processing Record 31 of Set 5 | kerema
# Processing Record 32 of Set 5 | tabiauea
# City "tabiauea" not found. Skipping...
# Processing Record 33 of Set 5 | endicott
# Processing Record 34 of Set 5 | angra
# City "angra" not found. Skipping...
# Processing Record 35 of Set 5 | natal
# Processing Record 36 of Set 5 | paamiut
# Processing Record 37 of Set 5 | santa cruz
# Processing Record 38 of Set 5 | glendive
# Processing Record 39 of Set 5 | bahia blanca
# Processing Record 40 of Set 5 | khatanga
# Processing Record 41 of Set 5 | komsomolskiy
# Processing Record 42 of Set 5 | saint-pierre
# Processing Record 43 of Set 5 | billings
# Processing Record 44 of Set 5 | port hardy
# Processing Record 45 of Set 5 | sitka
# Processing Record 46 of Set 5 | eureka
# Processing Record 47 of Set 5 | mount gambier
# Processing Record 48 of Set 5 | saint-georges
# Processing Record 49 of Set 5 | katsuura
# Processing Record 50 of Set 5 | rocha
# Processing Record 1 of Set 6 | guerrero negro
# Processing Record 2 of Set 6 | saint-philippe
# Processing Record 3 of Set 6 | roald
# Processing Record 4 of Set 6 | zambrow
# Processing Record 5 of Set 6 | humberto de campos
# Processing Record 6 of Set 6 | lakes entrance
# Processing Record 7 of Set 6 | barsovo
# Processing Record 8 of Set 6 | tete
# Processing Record 9 of Set 6 | gornopravdinsk
# Processing Record 10 of Set 6 | babai
# Processing Record 11 of Set 6 | sao jose da coroa grande
# Processing Record 12 of Set 6 | krasnoshchekovo
# Processing Record 13 of Set 6 | gulshat
# City "gulshat" not found. Skipping...
# Processing Record 14 of Set 6 | muswellbrook
# Processing Record 15 of Set 6 | leshukonskoye
# Processing Record 16 of Set 6 | ust-tsilma
# Processing Record 17 of Set 6 | scarborough
# Processing Record 18 of Set 6 | klaksvik
# Processing Record 19 of Set 6 | mendahara
# City "mendahara" not found. Skipping...
# Processing Record 20 of Set 6 | ambulu
# Processing Record 21 of Set 6 | gushikawa
# Processing Record 22 of Set 6 | neyshabur
# Processing Record 23 of Set 6 | svetlogorsk
# Processing Record 24 of Set 6 | salvador
# Processing Record 25 of Set 6 | poum
# Processing Record 26 of Set 6 | shumskiy
# Processing Record 27 of Set 6 | fortuna
# Processing Record 28 of Set 6 | westport
# Processing Record 29 of Set 6 | richards bay
# Processing Record 30 of Set 6 | petlawad
# Processing Record 31 of Set 6 | amderma
# City "amderma" not found. Skipping...
# Processing Record 32 of Set 6 | vaitupu
# City "vaitupu" not found. Skipping...
# Processing Record 33 of Set 6 | linxi
# Processing Record 34 of Set 6 | leningradskiy
# Processing Record 35 of Set 6 | dolinsk
# Processing Record 36 of Set 6 | ninghai
# Processing Record 37 of Set 6 | codrington
# Processing Record 38 of Set 6 | haines junction
# Processing Record 39 of Set 6 | thohoyandou
# Processing Record 40 of Set 6 | luderitz
# Processing Record 41 of Set 6 | okitipupa
# Processing Record 42 of Set 6 | airai
# Processing Record 43 of Set 6 | lasa
# Processing Record 44 of Set 6 | vreed en hoop
# City "vreed en hoop" not found. Skipping...
# Processing Record 45 of Set 6 | jiwani
# Processing Record 46 of Set 6 | havre-saint-pierre
# Processing Record 47 of Set 6 | faanui
# Processing Record 48 of Set 6 | kudahuvadhoo
# Processing Record 49 of Set 6 | darab
# Processing Record 50 of Set 6 | belyy yar
# Processing Record 1 of Set 7 | polyanka
# Processing Record 2 of Set 7 | amga
# Processing Record 3 of Set 7 | kirksville
# Processing Record 4 of Set 7 | antofagasta
# Processing Record 5 of Set 7 | gazanjyk
# Processing Record 6 of Set 7 | ararangua
# Processing Record 7 of Set 7 | abnub
# Processing Record 8 of Set 7 | susanville
# Processing Record 9 of Set 7 | venado tuerto
# Processing Record 10 of Set 7 | umzimvubu
# City "umzimvubu" not found. Skipping...
# Processing Record 11 of Set 7 | boca do acre
# Processing Record 12 of Set 7 | antalaha
# Processing Record 13 of Set 7 | chokurdakh
# Processing Record 14 of Set 7 | nome
# Processing Record 15 of Set 7 | faya
# Processing Record 16 of Set 7 | qasigiannguit
# Processing Record 17 of Set 7 | the valley
# Processing Record 18 of Set 7 | ngukurr
# City "ngukurr" not found. Skipping...
# Processing Record 19 of Set 7 | port elizabeth
# Processing Record 20 of Set 7 | lufilufi
# Processing Record 21 of Set 7 | emba
# Processing Record 22 of Set 7 | cairns
# Processing Record 23 of Set 7 | pangody
# Processing Record 24 of Set 7 | winnemucca
# Processing Record 25 of Set 7 | camacha
# Processing Record 26 of Set 7 | rosario
# Processing Record 27 of Set 7 | sorong
# Processing Record 28 of Set 7 | aktau
# Processing Record 29 of Set 7 | linares
# Processing Record 30 of Set 7 | tonantins
# Processing Record 31 of Set 7 | rudbar
# Processing Record 32 of Set 7 | abbeville
# Processing Record 33 of Set 7 | serenje
# Processing Record 34 of Set 7 | nanakuli
# Processing Record 35 of Set 7 | sembe
# Processing Record 36 of Set 7 | ola
# Processing Record 37 of Set 7 | ara
# Processing Record 38 of Set 7 | lolua
# City "lolua" not found. Skipping...
# Processing Record 39 of Set 7 | vestmanna
# Processing Record 40 of Set 7 | leeton
# Processing Record 41 of Set 7 | lata
# Processing Record 42 of Set 7 | saleaula
# City "saleaula" not found. Skipping...
# Processing Record 43 of Set 7 | aykhal
# Processing Record 44 of Set 7 | kulob
# Processing Record 45 of Set 7 | sataua
# City "sataua" not found. Skipping...
# Processing Record 46 of Set 7 | bengkulu
# Processing Record 47 of Set 7 | phan thiet
# Processing Record 48 of Set 7 | mae chan
# Processing Record 49 of Set 7 | fuyang
# Processing Record 50 of Set 7 | arcachon
# Processing Record 1 of Set 8 | riyadh
# Processing Record 2 of Set 8 | caravelas
# Processing Record 3 of Set 8 | kichera
# Processing Record 4 of Set 8 | yenagoa
# Processing Record 5 of Set 8 | kavaratti
# Processing Record 6 of Set 8 | araouane
# Processing Record 7 of Set 8 | madinat sittah uktubar
# Processing Record 8 of Set 8 | manadhoo
# Processing Record 9 of Set 8 | oruro
# Processing Record 10 of Set 8 | ures
# Processing Record 11 of Set 8 | yerbogachen
# Processing Record 12 of Set 8 | saldanha
# Processing Record 13 of Set 8 | zeya
# Processing Record 14 of Set 8 | bairiki
# Processing Record 15 of Set 8 | arman
# Processing Record 16 of Set 8 | kendal
# Processing Record 17 of Set 8 | praia
# Processing Record 18 of Set 8 | ozgon
# City "ozgon" not found. Skipping...
# Processing Record 19 of Set 8 | lokosovo
# Processing Record 20 of Set 8 | hervey bay
# Processing Record 21 of Set 8 | harrisburg
# Processing Record 22 of Set 8 | coquimbo
# Processing Record 23 of Set 8 | coihaique
# Processing Record 24 of Set 8 | mafinga
# Processing Record 25 of Set 8 | grand river south east
# City "grand river south east" not found. Skipping...
# Processing Record 26 of Set 8 | tsihombe
# City "tsihombe" not found. Skipping...
# Processing Record 27 of Set 8 | nantucket
# Processing Record 28 of Set 8 | srandakan
# Processing Record 29 of Set 8 | orebro
# Processing Record 30 of Set 8 | mandalgovi
# Processing Record 31 of Set 8 | miragoane
# Processing Record 32 of Set 8 | chingirlau
# Processing Record 33 of Set 8 | olinda
# Processing Record 34 of Set 8 | irtyshskiy
# Processing Record 35 of Set 8 | jiayuguan
# Processing Record 36 of Set 8 | palmer
# Processing Record 37 of Set 8 | bulgan
# Processing Record 38 of Set 8 | bolungarvik
# City "bolungarvik" not found. Skipping...
# Processing Record 39 of Set 8 | nazare
# Processing Record 40 of Set 8 | ostrow mazowiecka
# Processing Record 41 of Set 8 | taunggyi
# Processing Record 42 of Set 8 | sola
# Processing Record 43 of Set 8 | sao miguel
# Processing Record 44 of Set 8 | sooko
# Processing Record 45 of Set 8 | jeremoabo
# Processing Record 46 of Set 8 | macaboboni
# City "macaboboni" not found. Skipping...
# Processing Record 47 of Set 8 | mareeba
# Processing Record 48 of Set 8 | palencia
# Processing Record 49 of Set 8 | ipixuna
# Processing Record 50 of Set 8 | marsh harbour
# Processing Record 1 of Set 9 | iqaluit
# Processing Record 2 of Set 9 | ilebo
# Processing Record 3 of Set 9 | kindia
# Processing Record 4 of Set 9 | ambam
# Processing Record 5 of Set 9 | rawson
# Processing Record 6 of Set 9 | pueblo nuevo
# Processing Record 7 of Set 9 | aswan
# Processing Record 8 of Set 9 | medea
# Processing Record 9 of Set 9 | rio gallegos
# Processing Record 10 of Set 9 | grand forks
# Processing Record 11 of Set 9 | vynohradove
# Processing Record 12 of Set 9 | praxedis guerrero
# Processing Record 13 of Set 9 | chapais
# Processing Record 14 of Set 9 | poronaysk
# Processing Record 15 of Set 9 | grand-santi
# Processing Record 16 of Set 9 | yeletskiy
# City "yeletskiy" not found. Skipping...
# Processing Record 17 of Set 9 | louisbourg
# City "louisbourg" not found. Skipping...
# Processing Record 18 of Set 9 | sao filipe
# Processing Record 19 of Set 9 | uray
# Processing Record 20 of Set 9 | barcelos
# Processing Record 21 of Set 9 | rock springs
# Processing Record 22 of Set 9 | brae
# Processing Record 23 of Set 9 | yarmouth
# Processing Record 24 of Set 9 | gidole
# Processing Record 25 of Set 9 | ponta do sol
# Processing Record 26 of Set 9 | hasaki
# Processing Record 27 of Set 9 | lagdo
# Processing Record 28 of Set 9 | grindavik
# Processing Record 29 of Set 9 | romanovka
# Processing Record 30 of Set 9 | yumen
# Processing Record 31 of Set 9 | nuuk
# Processing Record 32 of Set 9 | tungor
# Processing Record 33 of Set 9 | san patricio
# Processing Record 34 of Set 9 | cervo
# Processing Record 35 of Set 9 | bukavu
# Processing Record 36 of Set 9 | damghan
# Processing Record 37 of Set 9 | necochea
# Processing Record 38 of Set 9 | santa eulalia del rio
# City "santa eulalia del rio" not found. Skipping...
# Processing Record 39 of Set 9 | ariogala
# Processing Record 40 of Set 9 | kelvington
# Processing Record 41 of Set 9 | kabo
# Processing Record 42 of Set 9 | khor
# Processing Record 43 of Set 9 | san andres
# Processing Record 44 of Set 9 | tungkang
# City "tungkang" not found. Skipping...
# Processing Record 45 of Set 9 | moroni
# Processing Record 46 of Set 9 | shahreza
# Processing Record 47 of Set 9 | aripuana
# Processing Record 48 of Set 9 | dabeiba
# Processing Record 49 of Set 9 | charneca de caparica
# Processing Record 50 of Set 9 | mandiana
# Processing Record 1 of Set 10 | ipilan
# Processing Record 2 of Set 10 | tiruchchendur
# Processing Record 3 of Set 10 | chitral
# Processing Record 4 of Set 10 | adrar
# Processing Record 5 of Set 10 | el alto
# Processing Record 6 of Set 10 | diffa
# Processing Record 7 of Set 10 | costa rica
# Processing Record 8 of Set 10 | fuerte olimpo
# Processing Record 9 of Set 10 | salalah
# Processing Record 10 of Set 10 | gimli
# Processing Record 11 of Set 10 | shizunai
# Processing Record 12 of Set 10 | palabuhanratu
# City "palabuhanratu" not found. Skipping...
# Processing Record 13 of Set 10 | hami
# Processing Record 14 of Set 10 | kristianstad
# Processing Record 15 of Set 10 | guayaramerin
# Processing Record 16 of Set 10 | methven
# Processing Record 17 of Set 10 | maple creek
# Processing Record 18 of Set 10 | urusha
# Processing Record 19 of Set 10 | general roca
# Processing Record 20 of Set 10 | sao joao da barra
# Processing Record 21 of Set 10 | euclides da cunha
# Processing Record 22 of Set 10 | turkistan
# Processing Record 23 of Set 10 | halalo
# City "halalo" not found. Skipping...
# Processing Record 24 of Set 10 | saint-francois
# Processing Record 25 of Set 10 | jumla
# Processing Record 26 of Set 10 | kavieng
# Processing Record 27 of Set 10 | goderich
# Processing Record 28 of Set 10 | denpasar
# Processing Record 29 of Set 10 | longlac
# City "longlac" not found. Skipping...
# Processing Record 30 of Set 10 | sabang
# Processing Record 31 of Set 10 | srikakulam
# Processing Record 32 of Set 10 | okhotsk
# Processing Record 33 of Set 10 | klichka
# Processing Record 34 of Set 10 | victoria
# Processing Record 35 of Set 10 | bafia
# Processing Record 36 of Set 10 | kalabo
# Processing Record 37 of Set 10 | barkhan
# Processing Record 38 of Set 10 | fasa
# Processing Record 39 of Set 10 | vardo
# Processing Record 40 of Set 10 | sentyabrskiy
# City "sentyabrskiy" not found. Skipping...
# Processing Record 41 of Set 10 | hambantota
# Processing Record 42 of Set 10 | berlevag
# Processing Record 43 of Set 10 | sisimiut
# Processing Record 44 of Set 10 | clyde river
# Processing Record 45 of Set 10 | russell
# Processing Record 46 of Set 10 | hammerfest
# Processing Record 47 of Set 10 | tilichiki
# Processing Record 48 of Set 10 | bathsheba
# Processing Record 49 of Set 10 | sopiste
# City "sopiste" not found. Skipping...
# Processing Record 50 of Set 10 | spirit river
# Processing Record 1 of Set 11 | cayenne
# Processing Record 2 of Set 11 | karla
# Processing Record 3 of Set 11 | ketchikan
# Processing Record 4 of Set 11 | chernyshevskiy
# Processing Record 5 of Set 11 | picos
# Processing Record 6 of Set 11 | orkney
# Processing Record 7 of Set 11 | sundumbili
# Processing Record 8 of Set 11 | atar
# Processing Record 9 of Set 11 | araguatins
# City "araguatins" not found. Skipping...
# Processing Record 10 of Set 11 | hare bay
# Processing Record 11 of Set 11 | noyabrsk
# Processing Record 12 of Set 11 | sinnamary
# Processing Record 13 of Set 11 | kandrian
# Processing Record 14 of Set 11 | mogadishu
# Processing Record 15 of Set 11 | san cristobal
# Processing Record 16 of Set 11 | flagstaff
# Processing Record 17 of Set 11 | skeldon
# Processing Record 18 of Set 11 | janakpur
# Processing Record 19 of Set 11 | gerash
# Processing Record 20 of Set 11 | yar-sale
# Processing Record 21 of Set 11 | doka
# Processing Record 22 of Set 11 | issenye
# Processing Record 23 of Set 11 | cockburn town
# Processing Record 24 of Set 11 | bereda
# Processing Record 25 of Set 11 | beloha
# Processing Record 26 of Set 11 | ler
# Processing Record 27 of Set 11 | srednekolymsk
# Processing Record 28 of Set 11 | grand gaube
# Processing Record 29 of Set 11 | ayr
# Processing Record 30 of Set 11 | shagonar
# Processing Record 31 of Set 11 | egvekinot
# Processing Record 32 of Set 11 | banda aceh
# Processing Record 33 of Set 11 | carupano
# Processing Record 34 of Set 11 | sulangan
# Processing Record 35 of Set 11 | tuatapere
# Processing Record 36 of Set 11 | dunedin
# Processing Record 37 of Set 11 | katherine
# Processing Record 38 of Set 11 | araguari
# Processing Record 39 of Set 11 | fort nelson
# Processing Record 40 of Set 11 | balingasay
# Processing Record 41 of Set 11 | gat
# Processing Record 42 of Set 11 | victoria point
# Processing Record 43 of Set 11 | synya
# Processing Record 44 of Set 11 | cabedelo
# Processing Record 45 of Set 11 | almas
# Processing Record 46 of Set 11 | redlands
# Processing Record 47 of Set 11 | kozelsk
# Processing Record 48 of Set 11 | urumqi
# Processing Record 49 of Set 11 | gorom-gorom
# Processing Record 50 of Set 11 | pouembout
# Processing Record 1 of Set 12 | tumannyy
# City "tumannyy" not found. Skipping...
# Processing Record 2 of Set 12 | mount darwin
# Processing Record 3 of Set 12 | makakilo city
# Processing Record 4 of Set 12 | kirkland lake
# Processing Record 5 of Set 12 | moerai
# Processing Record 6 of Set 12 | flic en flac
# Processing Record 7 of Set 12 | markova
# Processing Record 8 of Set 12 | daru
# Processing Record 9 of Set 12 | tuggurt
# City "tuggurt" not found. Skipping...
# Processing Record 10 of Set 12 | pangnirtung
# Processing Record 11 of Set 12 | nouadhibou
# Processing Record 12 of Set 12 | maniitsoq
# Processing Record 13 of Set 12 | banjar
# Processing Record 14 of Set 12 | yulara
# Processing Record 15 of Set 12 | saint-joseph
# Processing Record 16 of Set 12 | gouloure
# Processing Record 17 of Set 12 | collie
# Processing Record 18 of Set 12 | horsham
# Processing Record 19 of Set 12 | kailua
# Processing Record 20 of Set 12 | rio grande
# Processing Record 21 of Set 12 | batemans bay
# Processing Record 22 of Set 12 | lompoc
# Processing Record 23 of Set 12 | lhokseumawe
# Processing Record 24 of Set 12 | henties bay
# Processing Record 25 of Set 12 | shieli
# Processing Record 26 of Set 12 | bam
# Processing Record 27 of Set 12 | cartagena del chaira
# Processing Record 28 of Set 12 | pampa
# Processing Record 29 of Set 12 | urmary
# Processing Record 30 of Set 12 | shihezi
# Processing Record 31 of Set 12 | miri
# Processing Record 32 of Set 12 | druzhba
# Processing Record 33 of Set 12 | rosetta
# Processing Record 34 of Set 12 | bambanglipuro
# Processing Record 35 of Set 12 | lazaro cardenas
# Processing Record 36 of Set 12 | namibe
# Processing Record 37 of Set 12 | nago
# Processing Record 38 of Set 12 | manado
# Processing Record 39 of Set 12 | inirida
# Processing Record 40 of Set 12 | huarmey
# Processing Record 41 of Set 12 | gelgaudiskis
# Processing Record 42 of Set 12 | suamico
# Processing Record 43 of Set 12 | los llanos de aridane
# Processing Record 44 of Set 12 | sosva
# Processing Record 45 of Set 12 | burkhala
# City "burkhala" not found. Skipping...
# Processing Record 46 of Set 12 | nishihara
# Processing Record 47 of Set 12 | zwedru
# Processing Record 48 of Set 12 | orchard homes
# Processing Record 49 of Set 12 | imeni zhelyabova
# Processing Record 50 of Set 12 | ilhabela
# Processing Record 1 of Set 13 | port-cartier
# Processing Record 2 of Set 13 | waddan
# Processing Record 3 of Set 13 | calama
# Processing Record 4 of Set 13 | ostrovnoy
# Processing Record 5 of Set 13 | chuzhou
# Processing Record 6 of Set 13 | ucluelet
# Processing Record 7 of Set 13 | falealupo
# City "falealupo" not found. Skipping...
# Processing Record 8 of Set 13 | suicheng
# Processing Record 9 of Set 13 | goundam
# Processing Record 10 of Set 13 | linjiang
# Processing Record 11 of Set 13 | bethel
# Processing Record 12 of Set 13 | bandar
# Processing Record 13 of Set 13 | impfondo
# Processing Record 14 of Set 13 | walvis bay
# Processing Record 15 of Set 13 | traralgon
# Processing Record 16 of Set 13 | gambela
# Processing Record 17 of Set 13 | skalistyy
# City "skalistyy" not found. Skipping...
# Processing Record 18 of Set 13 | hidrolandia
# Processing Record 19 of Set 13 | sikonge
# Processing Record 20 of Set 13 | iki-burul
# Processing Record 21 of Set 13 | kasangulu
# Processing Record 22 of Set 13 | de-kastri
# Processing Record 23 of Set 13 | shuyskoye
# Processing Record 24 of Set 13 | west bay
# Processing Record 25 of Set 13 | palekh
# Processing Record 26 of Set 13 | skelleftea
# Processing Record 27 of Set 13 | port augusta
# Processing Record 28 of Set 13 | esso
# Processing Record 29 of Set 13 | severnyy
# Processing Record 30 of Set 13 | killybegs
# Processing Record 31 of Set 13 | akhmeta
# Processing Record 32 of Set 13 | faro
# Processing Record 33 of Set 13 | iaciara
# Processing Record 34 of Set 13 | coolum beach
# Processing Record 35 of Set 13 | barrington
# Processing Record 36 of Set 13 | baglan
# Processing Record 37 of Set 13 | karaj
# Processing Record 38 of Set 13 | hyeres
# Processing Record 39 of Set 13 | panlaitan
# Processing Record 40 of Set 13 | tocopilla
# Processing Record 41 of Set 13 | uarini
# Processing Record 42 of Set 13 | teya
# Processing Record 43 of Set 13 | berdigestyakh
# Processing Record 44 of Set 13 | labuhan
# Processing Record 45 of Set 13 | mahebourg
# Processing Record 46 of Set 13 | nova petropolis
# Processing Record 47 of Set 13 | paternion
# Processing Record 48 of Set 13 | harstad
# Processing Record 49 of Set 13 | new castle
# Processing Record 50 of Set 13 | avera
# Processing Record 1 of Set 14 | dolzhanskaya
# Processing Record 2 of Set 14 | kathu
# Processing Record 3 of Set 14 | konstantinovka
# Processing Record 4 of Set 14 | marquette
# Processing Record 5 of Set 14 | kununurra
# Processing Record 6 of Set 14 | kenitra
# Processing Record 7 of Set 14 | novikovo
# Processing Record 8 of Set 14 | portland
# Processing Record 9 of Set 14 | santa rosa
# Processing Record 10 of Set 14 | kagadi
# Processing Record 11 of Set 14 | rawlins
# Processing Record 12 of Set 14 | vestmannaeyjar
# Processing Record 13 of Set 14 | sungaipenuh
# Processing Record 14 of Set 14 | jalu
# Processing Record 15 of Set 14 | santa maria
# Processing Record 16 of Set 14 | maine-soroa
# Processing Record 17 of Set 14 | saint-leu
# Processing Record 18 of Set 14 | najran
# Processing Record 19 of Set 14 | bayir
# Processing Record 20 of Set 14 | mandera
# Processing Record 21 of Set 14 | houma
# Processing Record 22 of Set 14 | bolshaya chernigovka
# City "bolshaya chernigovka" not found. Skipping...
# Processing Record 23 of Set 14 | port shepstone
# Processing Record 24 of Set 14 | parana
# Processing Record 25 of Set 14 | nynashamn
# Processing Record 26 of Set 14 | lucea
# Processing Record 27 of Set 14 | bandar-e anzali
# Processing Record 28 of Set 14 | novomikhaylovskiy
# Processing Record 29 of Set 14 | saint-augustin
# Processing Record 30 of Set 14 | bembibre
# Processing Record 31 of Set 14 | polunochnoye
# Processing Record 32 of Set 14 | chimoio
# Processing Record 33 of Set 14 | pachelma
# Processing Record 34 of Set 14 | bac lieu
# Processing Record 35 of Set 14 | ngunguru
# Processing Record 36 of Set 14 | valparaiso
# Processing Record 37 of Set 14 | malabo
# Processing Record 38 of Set 14 | tarasovskiy
# Processing Record 39 of Set 14 | tiznit
# Processing Record 40 of Set 14 | port hedland
# Processing Record 41 of Set 14 | comodoro rivadavia
# Processing Record 42 of Set 14 | urucui
# Processing Record 43 of Set 14 | silver city
# Processing Record 44 of Set 14 | zyryanka
# Processing Record 45 of Set 14 | acapulco
# Processing Record 46 of Set 14 | chokwe
# Processing Record 47 of Set 14 | kasongo-lunda
# Processing Record 48 of Set 14 | cape coast
# Processing Record 49 of Set 14 | ayia marina
# Processing Record 50 of Set 14 | karaul
# City "karaul" not found. Skipping...
# Processing Record 1 of Set 15 | abu kamal
# Processing Record 2 of Set 15 | sao gabriel da cachoeira
# Processing Record 3 of Set 15 | santiago
# Processing Record 4 of Set 15 | honiara
# Processing Record 5 of Set 15 | chagda
# City "chagda" not found. Skipping...
# Processing Record 6 of Set 15 | rungata
# City "rungata" not found. Skipping...
# Processing Record 7 of Set 15 | tateyama
# Processing Record 8 of Set 15 | bonthe
# Processing Record 9 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 15 | harper
# Processing Record 11 of Set 15 | puerto del rosario
# Processing Record 12 of Set 15 | santarem
# Processing Record 13 of Set 15 | kokopo
# Processing Record 14 of Set 15 | turayf
# Processing Record 15 of Set 15 | nelson bay
# Processing Record 16 of Set 15 | tura
# Processing Record 17 of Set 15 | erdenet
# Processing Record 18 of Set 15 | alotau
# City "alotau" not found. Skipping...
# Processing Record 19 of Set 15 | severiano melo
# Processing Record 20 of Set 15 | sokolo
# Processing Record 21 of Set 15 | korla
# Processing Record 22 of Set 15 | shilovo
# Processing Record 23 of Set 15 | guntur
# Processing Record 24 of Set 15 | bria
# Processing Record 25 of Set 15 | karkaralinsk
# City "karkaralinsk" not found. Skipping...
# Processing Record 26 of Set 15 | naze
# Processing Record 27 of Set 15 | batagay
# Processing Record 28 of Set 15 | japura
# Processing Record 29 of Set 15 | half moon bay
# Processing Record 30 of Set 15 | ahuimanu
# Processing Record 31 of Set 15 | porto-vecchio
# Processing Record 32 of Set 15 | asau
# Processing Record 33 of Set 15 | martinsville
# Processing Record 34 of Set 15 | sechura
# Processing Record 35 of Set 15 | yoichi
# Processing Record 36 of Set 15 | bima
# Processing Record 37 of Set 15 | vrangel
# Processing Record 38 of Set 15 | ayan
# Processing Record 39 of Set 15 | chalchihuites
# Processing Record 40 of Set 15 | port blair
# Processing Record 41 of Set 15 | pakxan
# Processing Record 42 of Set 15 | port maria
# Processing Record 43 of Set 15 | sobolevo
# Processing Record 44 of Set 15 | aksu
# Processing Record 45 of Set 15 | sergeyevka
# Processing Record 46 of Set 15 | port moresby
# Processing Record 47 of Set 15 | puerto lempira
# Processing Record 48 of Set 15 | kapit
# Processing Record 49 of Set 15 | el badari
# City "el badari" not found. Skipping...
# Processing Record 50 of Set 15 | san ignacio
# Processing Record 1 of Set 16 | toora-khem
# Processing Record 2 of Set 16 | lafiagi
# Processing Record 3 of Set 16 | cangucu
# Processing Record 4 of Set 16 | werda
# Processing Record 5 of Set 16 | mansa
# Processing Record 6 of Set 16 | simav
# Processing Record 7 of Set 16 | keffi
# Processing Record 8 of Set 16 | bokspits
# City "bokspits" not found. Skipping...
# Processing Record 9 of Set 16 | meadow lake
# Processing Record 10 of Set 16 | zhanaozen
# Processing Record 11 of Set 16 | ginir
# Processing Record 12 of Set 16 | taft
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
cities_df = pd.DataFrame(city_data)

# %%
cities_df.to_csv("WeatherPy_Database.csv")
